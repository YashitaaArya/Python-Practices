# %% [markdown]
# <a href="https://colab.research.google.com/github/YashitaaArya/Python-Practices/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Importing csv data in notebook

# %%
data=pd.read_csv('/content/matches - matches.csv')

# %%
data
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Basic Attributes and Functions

# %%
data.head()
# top 5 data extracted
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
data.head(2)
# only top two rows data review
# Out:
#    id  season       city        date                team1  \
# 0   1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06       Mumbai Indians
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
#
#   player_of_match                                      venue         umpire1  \
# 0    Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal     AY Dandekar
# 1       SPD Smith    Maharashtra Cricket Association Stadium  A Nand Kishore
#
#     umpire2  umpire3
# 0  NJ Llong      NaN
# 1    S Ravi      NaN

# %%
data.tail()
# last 5 rows extracted by default
# Out:
#       id  season       city        date                team1  \
# 631  632    2016     Raipur  2016-05-22     Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24        Gujarat Lions
# 633  634    2016      Delhi  2016-05-25  Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27        Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29  Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 631  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 632  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 633        Kolkata Knight Riders        Kolkata Knight Riders         field
# 634          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 635  Royal Challengers Bangalore          Sunrisers Hyderabad           bat
#
#      result  dl_applied                       winner  win_by_runs  \
# 631  normal           0  Royal Challengers Bangalore            0
# ...

# %%
data.tail(1)
# last row
# Out:
#       id  season       city        date                team1  \
# 635  636    2016  Bangalore  2016-05-29  Sunrisers Hyderabad
#
#                            team2          toss_winner toss_decision  result  \
# 635  Royal Challengers Bangalore  Sunrisers Hyderabad           bat  normal
#
#      dl_applied               winner  win_by_runs  win_by_wickets  \
# 635           0  Sunrisers Hyderabad            8               0
#
#     player_of_match                  venue          umpire1       umpire2  \
# 635     BCJ Cutting  M Chinnaswamy Stadium  HDPK Dharmasena  BNJ Oxenford
#
#      umpire3
# 635      NaN

# %%
data.shape
# an attribute not function
# Out:
# (636, 18)

# %%
data.info()
# gives data preview
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    object
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
#  16  umpire2          635 non-null    object
# ...

# %%
data.describe()
# works only on numerical columns otherwise ignored
# provides high level summary of the data
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  636.000000   636.000000  636.000000   636.000000      636.000000
# mean   318.500000  2012.490566    0.025157    13.682390        3.372642
# std    183.741666     2.773026    0.156726    23.908877        3.420338
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    159.750000  2010.000000    0.000000     0.000000        0.000000
# 50%    318.500000  2012.000000    0.000000     0.000000        4.000000
# 75%    477.250000  2015.000000    0.000000    20.000000        7.000000
# max    636.000000  2017.000000    1.000000   146.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %% [markdown]
# Fetching rows and columns

# %%
data.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
data['winner']
# name of the column in the square bracket
# fetched in the form of a series
# Out:
# 0              Sunrisers Hyderabad
# 1           Rising Pune Supergiant
# 2            Kolkata Knight Riders
# 3                  Kings XI Punjab
# 4      Royal Challengers Bangalore
#                   ...
# 631    Royal Challengers Bangalore
# 632    Royal Challengers Bangalore
# 633            Sunrisers Hyderabad
# 634            Sunrisers Hyderabad
# 635            Sunrisers Hyderabad
# Name: winner, Length: 636, dtype: object

# %%
type(data['winner'])
# Out:
# pandas.core.series.Series

# %%
data[['team1', 'team2', 'winner']]
# fetching data of multiple columns
# Out:
#                            team1                        team2  \
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 1                 Mumbai Indians       Rising Pune Supergiant
# 2                  Gujarat Lions        Kolkata Knight Riders
# 3         Rising Pune Supergiant              Kings XI Punjab
# 4    Royal Challengers Bangalore             Delhi Daredevils
# ..                           ...                          ...
# 631             Delhi Daredevils  Royal Challengers Bangalore
# 632                Gujarat Lions  Royal Challengers Bangalore
# 633          Sunrisers Hyderabad        Kolkata Knight Riders
# 634                Gujarat Lions          Sunrisers Hyderabad
# 635          Sunrisers Hyderabad  Royal Challengers Bangalore
#
#                           winner
# 0            Sunrisers Hyderabad
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4    Royal Challengers Bangalore
# ...

# %%
type(data[['team1', 'team2', 'winner']])
# Out:
# pandas.core.frame.DataFrame

# %%
data['winner'].shape
# Out:
# (636,)

# %%
data.iloc[0]
# fetching only 1st row
# Out:
# id                                                         1
# season                                                  2017
# city                                               Hyderabad
# date                                              2017-04-05
# team1                                    Sunrisers Hyderabad
# team2                            Royal Challengers Bangalore
# toss_winner                      Royal Challengers Bangalore
# toss_decision                                          field
# result                                                normal
# dl_applied                                                 0
# winner                                   Sunrisers Hyderabad
# win_by_runs                                               35
# win_by_wickets                                             0
# player_of_match                                 Yuvraj Singh
# venue              Rajiv Gandhi International Stadium, Uppal
# ...

# %%
data.iloc[1]
# Out:
# id                                                       2
# season                                                2017
# city                                                  Pune
# date                                            2017-04-06
# team1                                       Mumbai Indians
# team2                               Rising Pune Supergiant
# toss_winner                         Rising Pune Supergiant
# toss_decision                                        field
# result                                              normal
# dl_applied                                               0
# winner                              Rising Pune Supergiant
# win_by_runs                                              0
# win_by_wickets                                           7
# player_of_match                                  SPD Smith
# venue              Maharashtra Cricket Association Stadium
# umpire1                                     A Nand Kishore
# ...

# %%
data.iloc[1:3]
# Out:
#    id  season    city        date           team1                   team2  \
# 1   2    2017    Pune  2017-04-06  Mumbai Indians  Rising Pune Supergiant
# 2   3    2017  Rajkot  2017-04-07   Gujarat Lions   Kolkata Knight Riders
#
#               toss_winner toss_decision  result  dl_applied  \
# 1  Rising Pune Supergiant         field  normal           0
# 2   Kolkata Knight Riders         field  normal           0
#
#                    winner  win_by_runs  win_by_wickets player_of_match  \
# 1  Rising Pune Supergiant            0               7       SPD Smith
# 2   Kolkata Knight Riders            0              10         CA Lynn
#
#                                      venue         umpire1    umpire2  umpire3
# 1  Maharashtra Cricket Association Stadium  A Nand Kishore     S Ravi      NaN
# 2   Saurashtra Cricket Association Stadium     Nitin Menon  CK Nandan      NaN

# %%
type(data.iloc[0])
# Out:
# pandas.core.series.Series

# %%
data.iloc[1:11:2]
# steps wala thing
# Out:
#    id  season       city        date                        team1  \
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 5   6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 7   8    2017     Indore  2017-04-10  Royal Challengers Bangalore
# 9  10    2017     Mumbai  2017-04-12          Sunrisers Hyderabad
#
#                     team2                  toss_winner toss_decision  result  \
# 1  Rising Pune Supergiant       Rising Pune Supergiant         field  normal
# 3         Kings XI Punjab              Kings XI Punjab         field  normal
# 5     Sunrisers Hyderabad          Sunrisers Hyderabad         field  normal
# 7         Kings XI Punjab  Royal Challengers Bangalore           bat  normal
# 9          Mumbai Indians               Mumbai Indians         field  normal
#
#    dl_applied                  winner  win_by_runs  win_by_wickets  \
# ...

# %%
data.iloc[[1,5,6]]
# fancy indexing from numpy
# fetching any index
# Out:
#    id  season       city        date                  team1  \
# 1   2    2017       Pune  2017-04-06         Mumbai Indians
# 5   6    2017  Hyderabad  2017-04-09          Gujarat Lions
# 6   7    2017     Mumbai  2017-04-09  Kolkata Knight Riders
#
#                     team2             toss_winner toss_decision  result  \
# 1  Rising Pune Supergiant  Rising Pune Supergiant         field  normal
# 5     Sunrisers Hyderabad     Sunrisers Hyderabad         field  normal
# 6          Mumbai Indians          Mumbai Indians         field  normal
#
#    dl_applied                  winner  win_by_runs  win_by_wickets  \
# 1           0  Rising Pune Supergiant            0               7
# 5           0     Sunrisers Hyderabad            0               9
# 6           0          Mumbai Indians            0               4
#
#   player_of_match                                      venue         umpire1  \
# 1       SPD Smith    Maharashtra Cricket Association Stadium  A Nand Kishore
# ...

# %%
data.iloc[:,[4,5,10]]
# [row description, column description]
# Out:
#                            team1                        team2  \
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 1                 Mumbai Indians       Rising Pune Supergiant
# 2                  Gujarat Lions        Kolkata Knight Riders
# 3         Rising Pune Supergiant              Kings XI Punjab
# 4    Royal Challengers Bangalore             Delhi Daredevils
# ..                           ...                          ...
# 631             Delhi Daredevils  Royal Challengers Bangalore
# 632                Gujarat Lions  Royal Challengers Bangalore
# 633          Sunrisers Hyderabad        Kolkata Knight Riders
# 634                Gujarat Lions          Sunrisers Hyderabad
# 635          Sunrisers Hyderabad  Royal Challengers Bangalore
#
#                           winner
# 0            Sunrisers Hyderabad
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4    Royal Challengers Bangalore
# ...

# %% [markdown]
# Filtering dataframe based on a given condition

# %%
data['city']=='Hyderabad'
# only where city is Hyderabad, ans=true else false.
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 631    False
# 632    False
# 633    False
# 634    False
# 635    False
# Name: city, Length: 636, dtype: bool

# %%
mask=data['city']=='Hyderabad'
data[mask]
# masked data
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 5      6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 18    19    2017  Hyderabad  2017-04-17          Sunrisers Hyderabad
# 20    21    2017  Hyderabad  2017-04-19          Sunrisers Hyderabad
# 35    36    2017  Hyderabad  2017-04-30          Sunrisers Hyderabad
# 42    43    2017  Hyderabad  2017-05-06       Rising Pune Supergiant
# 46    47    2017  Hyderabad  2017-05-08               Mumbai Indians
# 58    59    2017  Hyderabad  2017-05-21               Mumbai Indians
# 65    66    2008  Hyderabad  2008-04-22              Deccan Chargers
# 67    68    2008  Hyderabad  2008-04-24              Deccan Chargers
# 76    77    2008  Hyderabad  2008-05-01              Deccan Chargers
# 79    80    2008  Hyderabad  2008-05-25              Deccan Chargers
# 91    92    2008  Hyderabad  2008-05-11        Kolkata Knight Riders
# ...

# %%
data[mask].shape
# Out:
# (49, 18)

# %%
def get_city_match_count(city):
  mask=data['city']==city
  return data[mask].shape[0] # counting rows only

# %%
get_city_match_count('Bangalore')
# Out:
# 66

# %%
mask1=data['city']=='Hyderabad'
mask2=data['date']>'2010-01-01'
# extracting matches played in Hyd after 01-01-2010
data[mask1 & mask2] #masks are boolean vals, hence bitwise &
# mask2
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 5      6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 18    19    2017  Hyderabad  2017-04-17          Sunrisers Hyderabad
# 20    21    2017  Hyderabad  2017-04-19          Sunrisers Hyderabad
# 35    36    2017  Hyderabad  2017-04-30          Sunrisers Hyderabad
# 42    43    2017  Hyderabad  2017-05-06       Rising Pune Supergiant
# 46    47    2017  Hyderabad  2017-05-08               Mumbai Indians
# 58    59    2017  Hyderabad  2017-05-21               Mumbai Indians
# 235  236    2011  Hyderabad  2011-04-09              Deccan Chargers
# 244  245    2011  Hyderabad  2011-04-14              Deccan Chargers
# 248  249    2011  Hyderabad  2011-04-16              Deccan Chargers
# 259  260    2011  Hyderabad  2011-04-24               Mumbai Indians
# 274  275    2011  Hyderabad  2011-05-03        Kolkata Knight Riders
# ...

# %% [markdown]
# value_counts function

# %%
# har team ne kitne matches jeete,
# counts the frequency over the categorical dataset
data['winner'].value_counts()
# value counts only applies over series
# Out:
# winner
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: count, dtype: int64

# %% [markdown]
# Plot function for visualization

# %%
import matplotlib.pyplot as plt

# %%
# plotting a bar chart
# x-axis : category
# y-axis : count
data['winner'].value_counts().plot(kind='bar')
# plot fn works only on series
# Out:
# <Axes: xlabel='winner'>

# %%
data['winner'].value_counts().head().plot(kind='bar') #only top5
# Out:
# <Axes: xlabel='winner'>

# %%
data['winner'].value_counts().head().plot(kind='barh') #only top5
# horizontal chart
# Out:
# <Axes: ylabel='winner'>

# %%
data['toss_decision'].value_counts()
# Out:
# toss_decision
# field    363
# bat      273
# Name: count, dtype: int64

# %%
data['toss_decision'].value_counts().plot(kind='pie')
# toss_decision is a categorical column
# Out:
# <Axes: ylabel='count'>

# %%
data['win_by_runs'].value_counts().plot(kind='hist')
# win_by_runs is a numerical variable hence histogram
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# Let's understand series
#
# left column is index (always unique) and right column is value (variable).

# %%
myseries=data['winner'].value_counts()
myseries.index
# Out:
# Index(['Mumbai Indians', 'Chennai Super Kings', 'Kolkata Knight Riders',
#        'Royal Challengers Bangalore', 'Kings XI Punjab', 'Rajasthan Royals',
#        'Delhi Daredevils', 'Sunrisers Hyderabad', 'Deccan Chargers',
#        'Gujarat Lions', 'Pune Warriors', 'Rising Pune Supergiant',
#        'Kochi Tuskers Kerala', 'Rising Pune Supergiants'],
#       dtype='object', name='winner')

# %%
myseries.values
# Out:
# array([92, 79, 77, 73, 70, 63, 62, 42, 29, 13, 12, 10,  6,  5])

# %%
myseries['Kings XI Punjab']
# Out:
# np.int64(70)

# %%
data['team1'].value_counts()
# Out:
# team1
# Mumbai Indians                 82
# Kings XI Punjab                77
# Chennai Super Kings            77
# Royal Challengers Bangalore    70
# Kolkata Knight Riders          68
# Delhi Daredevils               63
# Rajasthan Royals               54
# Sunrisers Hyderabad            46
# Deccan Chargers                43
# Pune Warriors                  20
# Gujarat Lions                  14
# Rising Pune Supergiant          8
# Kochi Tuskers Kerala            7
# Rising Pune Supergiants         7
# Name: count, dtype: int64

# %%
data['team2'].value_counts()
# Out:
# team2
# Delhi Daredevils               84
# Royal Challengers Bangalore    82
# Kolkata Knight Riders          80
# Mumbai Indians                 75
# Kings XI Punjab                71
# Rajasthan Royals               64
# Chennai Super Kings            54
# Deccan Chargers                32
# Sunrisers Hyderabad            30
# Pune Warriors                  26
# Gujarat Lions                  16
# Rising Pune Supergiant          8
# Kochi Tuskers Kerala            7
# Rising Pune Supergiants         7
# Name: count, dtype: int64

# %%
# calculating how many matches played by one team
data['team1'].value_counts() + data['team2'].value_counts()
# all python operations work when two series have same index.
# Out:
# Chennai Super Kings            131
# Deccan Chargers                 75
# Delhi Daredevils               147
# Gujarat Lions                   30
# Kings XI Punjab                148
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          148
# Mumbai Indians                 157
# Pune Warriors                   46
# Rajasthan Royals               118
# Rising Pune Supergiant          16
# Rising Pune Supergiants         14
# Royal Challengers Bangalore    152
# Sunrisers Hyderabad             76
# Name: count, dtype: int64

# %% [markdown]
# Sort_values method

# %%
(data['team1'].value_counts() + data['team2'].value_counts()).sort_values()
# sorted all values by ascending order by default
# Out:
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# Rising Pune Supergiant          16
# Gujarat Lions                   30
# Pune Warriors                   46
# Deccan Chargers                 75
# Sunrisers Hyderabad             76
# Rajasthan Royals               118
# Chennai Super Kings            131
# Delhi Daredevils               147
# Kings XI Punjab                148
# Kolkata Knight Riders          148
# Royal Challengers Bangalore    152
# Mumbai Indians                 157
# Name: count, dtype: int64

# %%
(data['team1'].value_counts() + data['team2'].value_counts()).sort_values(ascending=False)
# Out:
# Mumbai Indians                 157
# Royal Challengers Bangalore    152
# Kings XI Punjab                148
# Kolkata Knight Riders          148
# Delhi Daredevils               147
# Chennai Super Kings            131
# Rajasthan Royals               118
# Sunrisers Hyderabad             76
# Deccan Chargers                 75
# Pune Warriors                   46
# Gujarat Lions                   30
# Rising Pune Supergiant          16
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# Name: count, dtype: int64

# %%
# let's sort entire data on the basis of city
data.sort_values('city')
# Out:
#       id  season       city        date                        team1  \
# 460  461    2014  Abu Dhabi  2014-04-18          Sunrisers Hyderabad
# 471  472    2014  Abu Dhabi  2014-04-26              Kings XI Punjab
# 470  471    2014  Abu Dhabi  2014-04-26  Royal Challengers Bangalore
# 464  465    2014  Abu Dhabi  2014-04-21          Chennai Super Kings
# 459  460    2014  Abu Dhabi  2014-04-18          Chennai Super Kings
# ..   ...     ...        ...         ...                          ...
# 466  467    2014        NaN  2014-04-23          Chennai Super Kings
# 468  469    2014        NaN  2014-04-25          Sunrisers Hyderabad
# 469  470    2014        NaN  2014-04-25               Mumbai Indians
# 474  475    2014        NaN  2014-04-28  Royal Challengers Bangalore
# 476  477    2014        NaN  2014-04-30          Sunrisers Hyderabad
#
#                      team2            toss_winner toss_decision  result  \
# ...

# %%
data.sort_values('city', ascending=False)
# sorted in descending order
# these sort data are temporary
# Out:
#       id  season           city        date                        team1  \
# 312  313    2012  Visakhapatnam  2012-04-07          Chennai Super Kings
# 622  623    2016  Visakhapatnam  2016-05-15               Mumbai Indians
# 615  616    2016  Visakhapatnam  2016-05-10          Sunrisers Hyderabad
# 612  613    2016  Visakhapatnam  2016-05-08          Sunrisers Hyderabad
# 624  625    2016  Visakhapatnam  2016-05-17             Delhi Daredevils
# ..   ...     ...            ...         ...                          ...
# 466  467    2014            NaN  2014-04-23          Chennai Super Kings
# 468  469    2014            NaN  2014-04-25          Sunrisers Hyderabad
# 469  470    2014            NaN  2014-04-25               Mumbai Indians
# 474  475    2014            NaN  2014-04-28  Royal Challengers Bangalore
# 476  477    2014            NaN  2014-04-30          Sunrisers Hyderabad
#
#                        team2              toss_winner toss_decision  result  \
# ...

# %%
data.sort_values('city', ascending=False, inplace=True)
# above command makes permanent changes

# %%
data
# Out:
#       id  season           city        date                        team1  \
# 312  313    2012  Visakhapatnam  2012-04-07          Chennai Super Kings
# 615  616    2016  Visakhapatnam  2016-05-10          Sunrisers Hyderabad
# 612  613    2016  Visakhapatnam  2016-05-08          Sunrisers Hyderabad
# 624  625    2016  Visakhapatnam  2016-05-17             Delhi Daredevils
# 536  537    2015  Visakhapatnam  2015-04-22          Sunrisers Hyderabad
# ..   ...     ...            ...         ...                          ...
# 466  467    2014            NaN  2014-04-23          Chennai Super Kings
# 468  469    2014            NaN  2014-04-25          Sunrisers Hyderabad
# 469  470    2014            NaN  2014-04-25               Mumbai Indians
# 474  475    2014            NaN  2014-04-28  Royal Challengers Bangalore
# 476  477    2014            NaN  2014-04-30          Sunrisers Hyderabad
#
#                        team2              toss_winner toss_decision  result  \
# ...

# %%
data.sort_values(['city', 'date'])
# Out:
#       id  season       city        date                        team1  \
# 457  458    2014  Abu Dhabi  2014-04-16        Kolkata Knight Riders
# 460  461    2014  Abu Dhabi  2014-04-18          Sunrisers Hyderabad
# 459  460    2014  Abu Dhabi  2014-04-18          Chennai Super Kings
# 464  465    2014  Abu Dhabi  2014-04-21          Chennai Super Kings
# 471  472    2014  Abu Dhabi  2014-04-26              Kings XI Punjab
# ..   ...     ...        ...         ...                          ...
# 466  467    2014        NaN  2014-04-23          Chennai Super Kings
# 468  469    2014        NaN  2014-04-25          Sunrisers Hyderabad
# 469  470    2014        NaN  2014-04-25               Mumbai Indians
# 474  475    2014        NaN  2014-04-28  Royal Challengers Bangalore
# 476  477    2014        NaN  2014-04-30          Sunrisers Hyderabad
#
#                      team2            toss_winner toss_decision  result  \
# ...

# %%
# city ascending, date descending
data.sort_values(['city', 'date'], ascending=[True, False])
# Out:
#       id  season       city        date                        team1  \
# 475  476    2014  Abu Dhabi  2014-04-29             Rajasthan Royals
# 471  472    2014  Abu Dhabi  2014-04-26              Kings XI Punjab
# 470  471    2014  Abu Dhabi  2014-04-26  Royal Challengers Bangalore
# 464  465    2014  Abu Dhabi  2014-04-21          Chennai Super Kings
# 460  461    2014  Abu Dhabi  2014-04-18          Sunrisers Hyderabad
# ..   ...     ...        ...         ...                          ...
# 468  469    2014        NaN  2014-04-25          Sunrisers Hyderabad
# 469  470    2014        NaN  2014-04-25               Mumbai Indians
# 466  467    2014        NaN  2014-04-23          Chennai Super Kings
# 461  462    2014        NaN  2014-04-19               Mumbai Indians
# 462  463    2014        NaN  2014-04-19        Kolkata Knight Riders
#
#                            team2                  toss_winner toss_decision  \
# ...

# %% [markdown]
# Drop_duplicates method

# %%
data.drop_duplicates(subset=['city'])
# Out:
#       id  season            city        date                        team1  \
# 312  313    2012   Visakhapatnam  2012-04-07          Chennai Super Kings
# 463  464    2014         Sharjah  2014-04-20             Rajasthan Royals
# 498  499    2014          Ranchi  2014-05-18          Chennai Super Kings
# 12    13    2017          Rajkot  2017-04-14       Rising Pune Supergiant
# 418  419    2013          Raipur  2013-04-28             Delhi Daredevils
# 37    38    2017            Pune  2017-05-01                Gujarat Lions
# 152  153    2009  Port Elizabeth  2009-05-10               Mumbai Indians
# 215  216    2010          Nagpur  2010-04-10          Chennai Super Kings
# 105  106    2008          Mumbai  2008-05-21              Kings XI Punjab
# 517  518    2015         Kolkata  2015-04-08               Mumbai Indians
# 277  278    2011           Kochi  2011-05-05         Kochi Tuskers Kerala
# 154  155    2009       Kimberley  2009-05-11              Deccan Chargers
# ...

# %%
data.drop_duplicates(subset=['city']).shape
# Out:
# (31, 18)

# %%
# ipl aajtak 31 unique states mei raha hai
# it is a temporary operation
# for permanent, inplace=True kardo.

# %%
# drop duplicate on multiple columns
data.drop_duplicates(subset=['city', 'season']).shape
#
# Out:
# (107, 18)

# %%
# check who's winner of each ipl season
data.drop_duplicates('season').shape
# data.drop_duplicates(subset=['season'], keep='last')[['season', 'winner']]
# Out:
# (10, 18)

# %%
data.drop_duplicates('season', keep='last')[['season','winner']].sort_values('season')
# Out:
#      season                       winner
# 69     2008             Rajasthan Royals
# 164    2009             Delhi Daredevils
# 197    2010             Rajasthan Royals
# 241    2011               Mumbai Indians
# 311    2012  Royal Challengers Bangalore
# 431    2013  Royal Challengers Bangalore
# 476    2014          Sunrisers Hyderabad
# 539    2015  Royal Challengers Bangalore
# 579    2016  Royal Challengers Bangalore
# 44     2017        Kolkata Knight Riders

# %% [markdown]
# Groupby method

# %%
df=data.groupby('season')
df

# %%
len(data) #no of rows
# Out:
# 636

# %%
len(df) #how many groups / seasons
# Out:
# 10

# %%
df.size()
# Out:
# season
# 2008    58
# 2009    57
# 2010    60
# 2011    73
# 2012    74
# 2013    76
# 2014    60
# 2015    59
# 2016    60
# 2017    59
# dtype: int64

# %%
df.size().sort_values(ascending=False)
# Out:
# season
# 2013    76
# 2012    74
# 2011    73
# 2016    60
# 2014    60
# 2010    60
# 2015    59
# 2017    59
# 2008    58
# 2009    57
# dtype: int64

# %%
df.first()
# Out:
#          id            city        date                   team1  \
# season
# 2008    106          Mumbai  2008-05-21         Kings XI Punjab
# 2009    153  Port Elizabeth  2009-05-10          Mumbai Indians
# 2010    216          Nagpur  2010-04-10     Chennai Super Kings
# 2011    305          Mumbai  2011-05-25   Kolkata Knight Riders
# 2012    313   Visakhapatnam  2012-04-07     Chennai Super Kings
# 2013    445          Ranchi  2013-05-15           Pune Warriors
# 2014    464         Sharjah  2014-04-20        Rajasthan Royals
# 2015    537   Visakhapatnam  2015-04-22     Sunrisers Hyderabad
# 2016    616   Visakhapatnam  2016-05-10     Sunrisers Hyderabad
# 2017     13          Rajkot  2017-04-14  Rising Pune Supergiant
#
#                               team2            toss_winner toss_decision  \
# season
# 2008                 Mumbai Indians         Mumbai Indians         field
# 2009    Royal Challengers Bangalore         Mumbai Indians           bat
# ...

# %%
df.last()
# Out:
#          id          city        date                        team1  \
# season
# 2008     70     Bangalore  2008-04-26  Royal Challengers Bangalore
# 2009    165  Bloemfontein  2009-05-17             Delhi Daredevils
# 2010    198     Ahmedabad  2010-03-28             Rajasthan Royals
# 2011    242     Bangalore  2011-04-12  Royal Challengers Bangalore
# 2012    312     Bangalore  2012-04-07  Royal Challengers Bangalore
# 2013    432     Bangalore  2013-04-09          Sunrisers Hyderabad
# 2014    477     Abu Dhabi  2014-04-30          Sunrisers Hyderabad
# 2015    540     Ahmedabad  2015-04-24             Rajasthan Royals
# 2016    580     Bangalore  2016-04-12  Royal Challengers Bangalore
# 2017     45     Bangalore  2017-05-07  Royal Challengers Bangalore
#
#                               team2                  toss_winner  \
# season
# 2008               Rajasthan Royals             Rajasthan Royals
# 2009               Rajasthan Royals             Delhi Daredevils
# ...

# %%
df.groups
# Out:
# {2008: [105, 81, 95, 114, 62, 115, 116, 98, 71, 85, 111, 104, 102, 94, 87, 63, 74, 112, 92, 100, 88, 82, 64, 77, 91, 113, 67, 65, 101, 76, 79, 108, 86, 75, 97, 99, 61, 66, 70, 90, 109, 106, 84, 78, 107, 80, 96, 93, 68, 72, 60, 83, 110, 103, 89, 73, 59, 69], 2009: [152, 121, 161, 131, 141, 139, 128, 154, 151, 150, 166, 173, 172, 162, 153, 140, 142, 163, 137, 149, 143, 126, 124, 130, 145, 157, 158, 159, 122, 144, 138, 167, 168, 127, 133, 134, 165, 135, 132, 146, 147, 148, 171, 169, 170, 136, 156, 155, 123, 119, 120, 125, 129, 118, 117, 160, 164], 2010: [215, 219, 209, 198, 200, 206, 187, 174, 175, 193, 233, 190, 220, 230, 231, 232, 177, 181, 226, 212, 207, 203, 229, 211, 218, 222, 224, 227, 228, 182, 208, 202, 184, 217, 199, 185, 188, 205, 210, 189, 201, 221, 178, 223, 214, 176, 192, 195, 204, 180, 225, 191, 216, 213, 196, 183, 179, 186, 194, 197], 2011: [304, 281, 298, 303, 276, 297, 294, 291, 272, 238, 246, 263, 249, 253, 243, 256, 280, 302, 269, 257, 254, 250, 239, 277, 268, 264, 23
# ...

# %%
data.iloc[105, :]
# Out:
# id                               207
# season                          2010
# city                          Mumbai
# date                      2010-04-03
# team1                 Mumbai Indians
# team2                Deccan Chargers
# toss_winner           Mumbai Indians
# toss_decision                    bat
# result                        normal
# dl_applied                         0
# winner                Mumbai Indians
# win_by_runs                       63
# win_by_wickets                     0
# player_of_match            AT Rayudu
# venue              Brabourne Stadium
# umpire1                  BR Doctrove
# umpire2                       S Ravi
# umpire3                          NaN
# Name: 206, dtype: object

# %%
# df.get_group('Bangalore')

# %%
# df.sum()

# %%
# df.mean()

# %%
df['win_by_runs'].mean()
# Out:
# season
# 2008    12.155172
# 2009    13.403509
# 2010    16.266667
# 2011    15.041096
# 2012    12.972973
# 2013    16.328947
# 2014    10.733333
# 2015    14.406780
# 2016    11.266667
# 2017    13.355932
# Name: win_by_runs, dtype: float64

# %% [markdown]
# isin function

# %%
data.groupby('city')['season'].count()
# Out:
# city
# Abu Dhabi          7
# Ahmedabad         12
# Bangalore         66
# Bloemfontein       2
# Cape Town          7
# Centurion         12
# Chandigarh        46
# Chennai           48
# Cuttack            7
# Delhi             60
# Dharamsala         9
# Durban            15
# East London        3
# Hyderabad         49
# Indore             5
# Jaipur            33
# Johannesburg       8
# Kanpur             4
# Kimberley          3
# Kochi              5
# Kolkata           61
# Mumbai            85
# Nagpur             3
# Port Elizabeth     7
# Pune              32
# Raipur             6
# Rajkot            10
# Ranchi             7
# Sharjah            6
# Visakhapatnam     11
# Name: season, dtype: int64

# %%
after15=data[data['season']>2015]

# %%
all_cities=after15.groupby('city')['season'].count()

# %%
x=all_cities>10
all_cities[x]
# Out:
# city
# Bangalore     17
# Chandigarh    11
# Delhi         14
# Hyderabad     15
# Kolkata       14
# Mumbai        12
# Pune          11
# Name: season, dtype: int64

# %%
cities_list=all_cities[x].index.tolist()

# %%
data[data['city'].isin(cities_list)].shape
# Out:
# (399, 18)

# %% [markdown]
# when mask ke liye bohot ho, isntaed of mask, use isin().

# %% [markdown]
# Merge method

# %%
# merging two csv
# new=delivery.merge(data, left_on='id', right_on='id')

# %%
# apply groupby on this new
# then sum()
# multi-index series
# new.groupby(['season','batsman'])['batsman_runs'].sum()
# new.groupby(['season','batsman'])['batsman_runs'].sum().reset_index()
# new.groupby(['season','batsman'])['batsman_runs'].sum().reset_index().sort_values(ascending=False).reset_index().drop_duplicates(subset='season', keep='first').sort_values('season')[['season','batsman']]

# %% [markdown]
# Pivot Table

# %%
# data.pivot_table(index=)

# %%
import seaborn as sns

# %%
# heatmap on pivot table

# %% [markdown]
# Corr function

# %%
data.corr(numeric_only=True)
# Out:
#                       id    season  dl_applied  win_by_runs  win_by_wickets  \
# id              1.000000  0.471087    0.024281    -0.010263       -0.015510
# season          0.471087  1.000000    0.004170    -0.016815       -0.000708
# dl_applied      0.024281  0.004170    1.000000    -0.010893       -0.011640
# win_by_runs    -0.010263 -0.016815   -0.010893     1.000000       -0.565181
# win_by_wickets -0.015510 -0.000708   -0.011640    -0.565181        1.000000
# umpire3              NaN       NaN         NaN          NaN             NaN
#
#                 umpire3
# id                  NaN
# season              NaN
# dl_applied          NaN
# win_by_runs         NaN
# win_by_wickets      NaN
# umpire3             NaN

# %%
sns.heatmap(data.corr(numeric_only=True))
# Out:
# <Axes: >

# %% [markdown]
# Rename columns

# %%
data.rename(columns={'city':'place', 'date':'DATE'})
# Out:
#       id  season          place        DATE                        team1  \
# 312  313    2012  Visakhapatnam  2012-04-07          Chennai Super Kings
# 615  616    2016  Visakhapatnam  2016-05-10          Sunrisers Hyderabad
# 612  613    2016  Visakhapatnam  2016-05-08          Sunrisers Hyderabad
# 624  625    2016  Visakhapatnam  2016-05-17             Delhi Daredevils
# 536  537    2015  Visakhapatnam  2015-04-22          Sunrisers Hyderabad
# ..   ...     ...            ...         ...                          ...
# 466  467    2014            NaN  2014-04-23          Chennai Super Kings
# 468  469    2014            NaN  2014-04-25          Sunrisers Hyderabad
# 469  470    2014            NaN  2014-04-25               Mumbai Indians
# 474  475    2014            NaN  2014-04-28  Royal Challengers Bangalore
# 476  477    2014            NaN  2014-04-30          Sunrisers Hyderabad
#
#                        team2              toss_winner toss_decision  result  \
# ...

# %% [markdown]
# set index and reset index methods

# %%
data.head(5)
# Out:
#       id  season           city        date                team1  \
# 312  313    2012  Visakhapatnam  2012-04-07  Chennai Super Kings
# 615  616    2016  Visakhapatnam  2016-05-10  Sunrisers Hyderabad
# 612  613    2016  Visakhapatnam  2016-05-08  Sunrisers Hyderabad
# 624  625    2016  Visakhapatnam  2016-05-17     Delhi Daredevils
# 536  537    2015  Visakhapatnam  2015-04-22  Sunrisers Hyderabad
#
#                        team2              toss_winner toss_decision  result  \
# 312          Deccan Chargers          Deccan Chargers         field  normal
# 615  Rising Pune Supergiants      Sunrisers Hyderabad           bat  normal
# 612           Mumbai Indians           Mumbai Indians         field  normal
# 624  Rising Pune Supergiants  Rising Pune Supergiants         field  normal
# 536    Kolkata Knight Riders    Kolkata Knight Riders         field  normal
#
#      dl_applied                   winner  win_by_runs  win_by_wickets  \
# ...

# %%
data.set_index('id')
# Out:
#      season           city        date                        team1  \
# id
# 313    2012  Visakhapatnam  2012-04-07          Chennai Super Kings
# 616    2016  Visakhapatnam  2016-05-10          Sunrisers Hyderabad
# 613    2016  Visakhapatnam  2016-05-08          Sunrisers Hyderabad
# 625    2016  Visakhapatnam  2016-05-17             Delhi Daredevils
# 537    2015  Visakhapatnam  2015-04-22          Sunrisers Hyderabad
# ..      ...            ...         ...                          ...
# 467    2014            NaN  2014-04-23          Chennai Super Kings
# 469    2014            NaN  2014-04-25          Sunrisers Hyderabad
# 470    2014            NaN  2014-04-25               Mumbai Indians
# 475    2014            NaN  2014-04-28  Royal Challengers Bangalore
# 477    2014            NaN  2014-04-30          Sunrisers Hyderabad
#
#                        team2              toss_winner toss_decision  result  \
# id
# ...

# %%
data.reset_index()
# Out:
#      index   id  season           city        date  \
# 0      312  313    2012  Visakhapatnam  2012-04-07
# 1      615  616    2016  Visakhapatnam  2016-05-10
# 2      612  613    2016  Visakhapatnam  2016-05-08
# 3      624  625    2016  Visakhapatnam  2016-05-17
# 4      536  537    2015  Visakhapatnam  2015-04-22
# ..     ...  ...     ...            ...         ...
# 631    466  467    2014            NaN  2014-04-23
# 632    468  469    2014            NaN  2014-04-25
# 633    469  470    2014            NaN  2014-04-25
# 634    474  475    2014            NaN  2014-04-28
# 635    476  477    2014            NaN  2014-04-30
#
#                            team1                    team2  \
# 0            Chennai Super Kings          Deccan Chargers
# 1            Sunrisers Hyderabad  Rising Pune Supergiants
# 2            Sunrisers Hyderabad           Mumbai Indians
# 3               Delhi Daredevils  Rising Pune Supergiants
# ...

# %%
# reset index converts a series into a dataframe

# %% [markdown]
# Handling missing values

# %%
# dropna()
data.shape
# Out:
# (636, 18)

# %%
data.dropna().shape
# for any null value row, entire row would be eliminated
# Out:
# (0, 18)

# %%
data.dropna(how='all').shape
# Out:
# (636, 18)

# %%
data.dropna(axis=1, how='all').shape
# Out:
# (636, 17)

# %%
# data.dropna(subset=["price"], axis=0, inplace=True)
# data.reset_index(drop=True, inplace=True)
# it's a union operation

# %% [markdown]
# fillna method

# %%
data.fillna(0)
# Out:
#       id  season           city        date                        team1  \
# 312  313    2012  Visakhapatnam  2012-04-07          Chennai Super Kings
# 615  616    2016  Visakhapatnam  2016-05-10          Sunrisers Hyderabad
# 612  613    2016  Visakhapatnam  2016-05-08          Sunrisers Hyderabad
# 624  625    2016  Visakhapatnam  2016-05-17             Delhi Daredevils
# 536  537    2015  Visakhapatnam  2015-04-22          Sunrisers Hyderabad
# ..   ...     ...            ...         ...                          ...
# 466  467    2014              0  2014-04-23          Chennai Super Kings
# 468  469    2014              0  2014-04-25          Sunrisers Hyderabad
# 469  470    2014              0  2014-04-25               Mumbai Indians
# 474  475    2014              0  2014-04-28  Royal Challengers Bangalore
# 476  477    2014              0  2014-04-30          Sunrisers Hyderabad
#
#                        team2              toss_winner toss_decision  result  \
# ...

# %%
data['city'].fillna("-", inplace=True)
# Out:
# /tmp/ipykernel_13041/821126460.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['city'].fillna("-", inplace=True)
